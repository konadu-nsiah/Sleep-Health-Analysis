# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from scipy.stats import norm

# %%
data=pd.read_excel("Excel Project Dataset.xlsx")
data.head(200)
# Out:
#         ID Marital Status Gender  Income  Children        Education  \
# 0    12496              M      F   40000         1        Bachelors
# 1    24107              M      M   30000         3  Partial College
# 2    14177              M      M   80000         5  Partial College
# 3    24381              S      M   70000         0        Bachelors
# 4    25597              S      M   30000         0        Bachelors
# ..     ...            ...    ...     ...       ...              ...
# 195  25559              S      M   20000         0        Bachelors
# 196  16209              S      F   50000         0  Graduate Degree
# 197  11147              M      M   60000         2  Graduate Degree
# 198  15214              S      F  100000         0  Graduate Degree
# 199  11453              S      M   80000         0        Bachelors
#
#          Occupation Home Owner  Cars Commute Distance   Region  Age  \
# 0    Skilled Manual        Yes     0        0-1 Miles   Europe   42
# ...

# %%
data.describe()
# Out:
#                  ID         Income     Children         Cars          Age
# count   1026.000000    1026.000000  1026.000000  1026.000000  1026.000000
# mean   19969.196881   56208.576998     1.892788     1.437622    44.138402
# std     5332.672942   31293.284007     1.626670     1.125538    11.349282
# min    11000.000000   10000.000000     0.000000     0.000000    25.000000
# 25%    15304.750000   30000.000000     0.000000     1.000000    35.000000
# 50%    19744.000000   60000.000000     2.000000     1.000000    43.000000
# 75%    24457.750000   70000.000000     3.000000     2.000000    52.000000
# max    29447.000000  170000.000000     5.000000     4.000000    89.000000

# %%
mu=0
sigma= 1
N= 1000
X =np.random.normal(mu,sigma,N)
# Population distribution
x_values = np.arange(-10, 10, 0.01)
y_values=norm.pdf(x_values)
# Sample histogram with population distribution
counts, bins,ignored=plt.hist(X, 60, density=True, color="Purple",label="Sampling distribution")
plt.plot(x_values, y_values, color='y', linewidth=2.5, label='population distribution')
plt.title("Showing the normal distribution from customrs' income")
plt.ylabel("Probability")
plt.legend()
plt.show()
